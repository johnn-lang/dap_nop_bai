# %%
import pandas as pd

# %%
data=pd.read_csv('https://raw.githubusercontent.com/lenhattung/SP26-AI1904-DAP391m/refs/heads/main/lab_part_2/01%20-%20Linear%20and%20logistic%20regression/titanic.csv')
data.head(5)
# Out:
#    passenger_id  pclass  survived  \
# 0             1       1         1
# 1             2       1         1
# 2             3       1         0
# 3             4       1         0
# 4             5       1         0
#
#                                               name  sex      age  sibsp  \
# 0                    Allen, Miss. Elisabeth Walton    1  29.0000      0
# 1                   Allison, Master. Hudson Trevor    0   0.9167      1
# 2                     Allison, Miss. Helen Loraine    1   2.0000      1
# 3             Allison, Mr. Hudson Joshua Creighton    0  30.0000      1
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)    1  25.0000      1
#
#    parch  ticket      fare    cabin embarked boat   body  \
# 0      0   24160  211.3375       B5        S    2    NaN
# 1      2  113781  151.5500  C22 C26        S   11    NaN
# 2      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   passenger_id  1309 non-null   int64
#  1   pclass        1309 non-null   int64
#  2   survived      1309 non-null   int64
#  3   name          1309 non-null   object
#  4   sex           1309 non-null   int64
#  5   age           1046 non-null   float64
#  6   sibsp         1309 non-null   int64
#  7   parch         1309 non-null   int64
#  8   ticket        1309 non-null   object
#  9   fare          1308 non-null   float64
#  10  cabin         295 non-null    object
#  11  embarked      1307 non-null   object
#  12  boat          486 non-null    object
#  13  body          121 non-null    float64
#  14  home.dest     745 non-null    object
# dtypes: float64(3), int64(6), object(6)
# memory usage: 153.5+ KB

# %%
for col in data.columns:
  print(col, data[col].value_counts)
# Out:
# passenger_id <bound method IndexOpsMixin.value_counts of 0          1
# 1          2
# 2          3
# 3          4
# 4          5
#         ...
# 1304    1305
# 1305    1306
# 1306    1307
# 1307    1308
# 1308    1309
# Name: passenger_id, Length: 1309, dtype: int64>
# pclass <bound method IndexOpsMixin.value_counts of 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1304    3
# 1305    3
# 1306    3
# 1307    3
# 1308    3
# Name: pclass, Length: 1309, dtype: int64>
# survived <bound method IndexOpsMixin.value_counts of 0       1
# 1       1
# 2       0
# 3       0
# 4       0
#        ..
# 1304    0
# 1305    0
# 1306    0
# 1307    0
# 1308    0
# Name: survived, Length: 1309, dtype: int64>
# name <bound method IndexOpsMixin.value_counts of 0                         Allen, Miss. Elisabeth Walton
# 1                        Allison, Master. Hudson Trevor
# 2                          Allison, Miss. Helen Loraine
# 3                  Allison, Mr. Hudson Joshua Creighton
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#                              ...
# 1304                               Zabour, Miss. Hileni
# 1305                              Zabour, Miss. Thamine
# 1306                          Zakarian, Mr. Mapriededer
# 1307                                Zakarian, Mr. Ortin
# 1308                                 Zimmerman, Mr. Leo
# Name: name, Length: 1309, dtype: object>
# sex <bound method IndexOpsMixin.value_counts of 0       1
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 1304    1
# 1305    1
# 1306    0
# 1307    0
# 1308    0
# Name: sex, Length: 1309, dtype: int64>
# age <bound method IndexOpsMixin.value_counts of 0       29.0000
# 1        0.9167
# 2        2.0000
# 3       30.0000
# 4       25.0000
#          ...
# 1304    14.5000
# 1305        NaN
# 1306    26.5000
# 1307    27.0000
# 1308    29.0000
# Name: age, Length: 1309, dtype: float64>
# sibsp <bound method IndexOpsMixin.value_counts of 0       0
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1304    1
# 1305    1
# 1306    0
# 1307    0
# 1308    0
# Name: sibsp, Length: 1309, dtype: int64>
# parch <bound method IndexOpsMixin.value_counts of 0       0
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 1304    0
# 1305    0
# 1306    0
# 1307    0
# 1308    0
# Name: parch, Length: 1309, dtype: int64>
# ticket <bound method IndexOpsMixin.value_counts of 0        24160
# 1       113781
# 2       113781
# 3       113781
# 4       113781
#          ...
# 1304      2665
# 1305      2665
# 1306      2656
# 1307      2670
# 1308    315082
# Name: ticket, Length: 1309, dtype: object>
# fare <bound method IndexOpsMixin.value_counts of 0       211.3375
# 1       151.5500
# 2       151.5500
# 3       151.5500
# 4       151.5500
#           ...
# 1304     14.4542
# 1305     14.4542
# 1306      7.2250
# 1307      7.2250
# 1308      7.8750
# Name: fare, Length: 1309, dtype: float64>
# cabin <bound method IndexOpsMixin.value_counts of 0            B5
# 1       C22 C26
# 2       C22 C26
# 3       C22 C26
# 4       C22 C26
#          ...
# 1304        NaN
# 1305        NaN
# 1306        NaN
# 1307        NaN
# 1308        NaN
# Name: cabin, Length: 1309, dtype: object>
# embarked <bound method IndexOpsMixin.value_counts of 0       S
# 1       S
# 2       S
# 3       S
# 4       S
#        ..
# 1304    C
# 1305    C
# 1306    C
# 1307    C
# 1308    S
# Name: embarked, Length: 1309, dtype: object>
# boat <bound method IndexOpsMixin.value_counts of 0         2
# 1        11
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 1304    NaN
# 1305    NaN
# 1306    NaN
# 1307    NaN
# 1308    NaN
# Name: boat, Length: 1309, dtype: object>
# body <bound method IndexOpsMixin.value_counts of 0         NaN
# 1         NaN
# 2         NaN
# 3       135.0
# 4         NaN
#         ...
# 1304    328.0
# 1305      NaN
# 1306    304.0
# 1307      NaN
# 1308      NaN
# Name: body, Length: 1309, dtype: float64>
# home.dest <bound method IndexOpsMixin.value_counts of 0                          St Louis, MO
# 1       Montreal, PQ / Chesterville, ON
# 2       Montreal, PQ / Chesterville, ON
# 3       Montreal, PQ / Chesterville, ON
# 4       Montreal, PQ / Chesterville, ON
#                      ...
# 1304                                NaN
# 1305                                NaN
# 1306                                NaN
# 1307                                NaN
# 1308                                NaN
# Name: home.dest, Length: 1309, dtype: object>

# %%
data['sex'].dtype
# Out:
# dtype('int64')

# %%
data=pd.get_dummies(data, columns=['sex', 'embarked','survived','pclass'])
data.head(5)
# Out:
#    passenger_id                                             name      age  \
# 0             1                    Allen, Miss. Elisabeth Walton  29.0000
# 1             2                   Allison, Master. Hudson Trevor   0.9167
# 2             3                     Allison, Miss. Helen Loraine   2.0000
# 3             4             Allison, Mr. Hudson Joshua Creighton  30.0000
# 4             5  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  25.0000
#
#    sibsp  parch  ticket      fare    cabin boat   body  ...  sex_0  sex_1  \
# 0      0      0   24160  211.3375       B5    2    NaN  ...  False   True
# 1      1      2  113781  151.5500  C22 C26   11    NaN  ...   True  False
# 2      1      2  113781  151.5500  C22 C26  NaN    NaN  ...  False   True
# 3      1      2  113781  151.5500  C22 C26  NaN  135.0  ...   True  False
# 4      1      2  113781  151.5500  C22 C26  NaN    NaN  ...  False   True
#
#    embarked_C  embarked_Q  embarked_S  survived_0  survived_1  pclass_1  \
# 0       False       False        True       False        True      True
# 1       False       False        True       False        True      True
# 2       False       False        True        True       False      True
# 3       False       False        True        True       False      True
# 4       False       False        True        True       False      True
#
#    pclass_2  pclass_3
# 0     False     False
# 1     False     False
# 2     False     False
# 3     False     False
# 4     False     False
#
# [5 rows x 21 columns]
